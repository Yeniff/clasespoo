# %% [markdown]
# <a href="https://colab.research.google.com/github/Yeniff/clasespoo/blob/main/Pandas_y_Matploitlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
preprocessed_train_data=pd.read_csv("preprocessed_train_data.csv")

# %%
preprocessed_train_data.head()
# Out:
#          Id  MSSubClass  LotFrontage  ...  SaleType  SaleCondition  SalePrice
# 0 -1.730865    0.430516    -0.096661  ... -0.255912      -0.196149     208500
# 1 -1.728492   -1.128983     0.507890  ... -0.255912      -0.196149     181500
# 2 -1.726120    0.430516     0.034709  ... -0.255912      -0.196149     223500
# 3 -1.723747    0.649335    -0.329709  ... -0.255912      -1.177950     140000
# 4 -1.721374    0.430516     0.649945  ... -0.255912      -0.196149     250000
#
# [5 rows x 77 columns]

# %% [markdown]
# Muestra las primeras 20 columnas y filas del dataset

# %%
preprocessed_train_data.head(20)
# Out:
#           Id  MSSubClass  LotFrontage  ...  SaleType  SaleCondition  SalePrice
# 0  -1.730865    0.430516    -0.096661  ... -0.255912      -0.196149     208500
# 1  -1.728492   -1.128983     0.507890  ... -0.255912      -0.196149     181500
# 2  -1.726120    0.430516     0.034709  ... -0.255912      -0.196149     223500
# 3  -1.723747    0.649335    -0.329709  ... -0.255912      -1.177950     140000
# 4  -1.721374    0.430516     0.649945  ... -0.255912      -0.196149     250000
# 5  -1.719002    0.171708     0.684401  ... -0.255912      -0.196149     143000
# 6  -1.716629   -1.128983     0.319983  ... -0.255912      -0.196149     307000
# 7  -1.714256    0.430516     0.947710  ... -0.255912      -0.196149     200000
# 8  -1.711883    0.171708    -0.802890  ... -0.255912      -1.177950     129900
# 9  -1.709511    2.066764    -0.860546  ... -0.255912      -0.196149     118000
# 10 -1.707138   -1.128983     0.119108  ... -0.255912      -0.196149     129500
# ...

# %% [markdown]
# Muestra las 10 ultimas filas y columnas del dataset

# %%
preprocessed_train_data.tail(10)
# Out:
#             Id  MSSubClass  LotFrontage  ...  SaleType  SaleCondition  SalePrice
# 1450  1.709511    1.006081    -0.329709  ... -0.255912      -0.196149     136000
# 1451  1.711883   -1.128983     0.434176  ...  3.209390       3.128021     287090
# 1452  1.714256    1.990015    -1.899021  ... -0.255912      -0.196149     145000
# 1453  1.716629   -1.128983     0.850820  ... -0.255912      -1.177950      84500
# 1454  1.719002   -1.128983    -0.234240  ... -0.255912      -0.196149     185000
# 1455  1.721374    0.430516    -0.234240  ... -0.255912      -0.196149     175000
# 1456  1.723747   -1.128983     0.684401  ... -0.255912      -0.196149     210000
# 1457  1.726120    0.649335    -0.052209  ... -0.255912      -0.196149     266500
# 1458  1.728492   -1.128983     0.034709  ... -0.255912      -0.196149     142125
# 1459  1.730865   -1.128983     0.319983  ... -0.255912      -0.196149     147500
#
# [10 rows x 77 columns]

# %% [markdown]
# Muestra el nombre de las columnas del dataset

# %%
preprocessed_train_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'MSZoning', 'Street', 'LotShape',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir',
# ...

# %% [markdown]
# Muestra el tipo de datos de las columnas del dataset

# %%
preprocessed_train_data.dtypes
# Out:
# Id               float64
# MSSubClass       float64
# LotFrontage      float64
# LotArea          float64
# OverallQual      float64
#                   ...
# GarageCond       float64
# PavedDrive       float64
# SaleType         float64
# SaleCondition    float64
# SalePrice          int64
# Length: 77, dtype: object

# %%
preprocessed_train_data['SalePrice'].plot(title = 'Precio vivienda')

# %%
plt.plot(preprocessed_train_data ['SalePrice'],color='deeppink', linestyle='dashed', linewidth=1,
         marker='o', markersize=5, markerfacecolor='orange',label='SalPrice')
plt.legend(loc='upper left')

# %%
plt.scatter(preprocessed_train_data['Id'],preprocessed_train_data ['SalePrice'])
plt.show()

# %% [markdown]
# Metodo basico para sacar los mas altos de las columnas del dataset

# %%
preprocessed_train_data.max()
# Out:
# Id                    1.730865
# MSSubClass            2.066764
# LotFrontage           4.479749
# LotArea               6.125793
# OverallQual           2.821425
#                      ...
# GarageCond            7.777068
# PavedDrive            3.739087
# SaleType              3.209390
# SaleCondition         3.128021
# SalePrice        755000.000000
# Length: 77, dtype: float64

# %% [markdown]
# Metodo para sacar los mas altos por fila

# %%
preprocessed_train_data.max(axis=1)
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
#           ...
# 1455    175000.0
# 1456    210000.0
# 1457    266500.0
# 1458    142125.0
# 1459    147500.0
# Length: 1460, dtype: float64

# %% [markdown]
# Metodo para sacar el mas alto del dataset

# %%
preprocessed_train_data.max().max()
# Out:
# 755000.0

# %% [markdown]
# Metodo para tener en cuenta los valores nulos del dataset

# %%
preprocessed_train_data.max(axis=1, skipna=False)
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
#           ...
# 1455    175000.0
# 1456    210000.0
# 1457    266500.0
# 1458    142125.0
# 1459    147500.0
# Length: 1460, dtype: float64

# %% [markdown]
# Metodo para saber la posicion de los valores mas alto de las columnas

# %%
preprocessed_train_data.idxmax()
# Out:
# Id               1459
# MSSubClass          9
# LotFrontage       934
# LotArea           313
# OverallQual        58
#                  ...
# GarageCond        246
# PavedDrive         21
# SaleType           11
# SaleCondition      11
# SalePrice         691
# Length: 77, dtype: int64

# %% [markdown]
# Metodo para saber la posicion de los valores mas altos de las filas

# %%
preprocessed_train_data.idxmax(axis=1)
# Out:
# 0       SalePrice
# 1       SalePrice
# 2       SalePrice
# 3       SalePrice
# 4       SalePrice
#           ...
# 1455    SalePrice
# 1456    SalePrice
# 1457    SalePrice
# 1458    SalePrice
# 1459    SalePrice
# Length: 1460, dtype: object

# %% [markdown]
# Metodo basico para sacar los valores mas bajos de las columnas del dataset

# %%
preprocessed_train_data.min()
# Out:
# Id                  -1.730865
# MSSubClass          -1.128983
# LotFrontage         -3.386312
# LotArea             -3.751843
# OverallQual         -3.688413
#                      ...
# GarageCond          -8.009542
# PavedDrive          -0.289745
# SaleType            -1.835001
# SaleCondition       -2.505005
# SalePrice        34900.000000
# Length: 77, dtype: float64

# %% [markdown]
# Metodo para sacar los mas bajos por fila

# %%
preprocessed_train_data.min(axis=1)
# Out:
# 0      -1.730865
# 1      -2.680904
# 2      -1.726120
# 3      -3.392977
# 4      -1.777516
#           ...
# 1455   -1.414140
# 1456   -1.985730
# 1457   -3.392977
# 1458   -2.059511
# 1459   -1.512014
# Length: 1460, dtype: float64

# %% [markdown]
# Metodo para sacar el mas bajo del dataset

# %%
preprocessed_train_data.min().min()
# Out:
# -15.567059238447495

# %%
preprocessed_train_data.min(axis=1, skipna=False)
# Out:
# 0      -1.730865
# 1      -2.680904
# 2      -1.726120
# 3      -3.392977
# 4      -1.777516
#           ...
# 1455   -1.414140
# 1456   -1.985730
# 1457   -3.392977
# 1458   -2.059511
# 1459   -1.512014
# Length: 1460, dtype: float64

# %% [markdown]
# Metodo para saber la posicion de los valores mas bajos de las columnas

# %%
preprocessed_train_data.idxmin()
# Out:
# Id                 0
# MSSubClass         1
# LotFrontage       75
# LotArea          956
# OverallQual      375
#                 ...
# GarageCond       268
# PavedDrive         0
# SaleType         942
# SaleCondition     39
# SalePrice        495
# Length: 77, dtype: int64

# %% [markdown]
# Metodo para saber la posicion de los valores mas bajos de las filas

# %%
preprocessed_train_data.idxmin(axis=1)
# Out:
# 0                 Id
# 1         Condition1
# 2                 Id
# 3           BsmtCond
# 4         GarageCars
#             ...
# 1455      BsmtFinSF1
# 1456    BsmtFinType2
# 1457        BsmtCond
# 1458       BsmtUnfSF
# 1459    GarageFinish
# Length: 1460, dtype: object
